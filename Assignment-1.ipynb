# %%
#    Q1) Who developed python programming language ?

#    Ans) Python was developed by Guido van Rossum. 



#    Q2) Which type of programming does python support ?

#    Ans) Python is a general purpose programming language and it support object oriented,
#         procedure oriented, functional and scripting programming language.
        

#    Q3) Is python case sensitive when dealing with identifier?

#    Ans) Yes, python is case sensitive programming language.



#    Q4) What is the correct extension of python file?

#    Ans) The correct extension of python file is .ipynb.



#    Q5) Is python code compiled or interpreted?

#    Ans) Python code is interpreted programming language


#    Q6) Name a few blocks of code used to define in python language?

#    Ans) A module, A function body, and A class definition.



#    Q7) State a character to give single line comment in python?

#    Ans) #.




#    Q8) Mention a function whcih can help us to find the  version of python that we are currently working on?

#    Ans) python –version.



#    Q9) Python supports the creation of anonymous function at runtime, using a construct called?
         
#    Ans) lambda.




#    Q10) What does pip stands for python?
         
#    Ans) Preferred Installer Program.



#    Q11) Mention a few built in function in python?
         
#    Ans) type(), len(), input(), print(), count(), index().




#    Q12) what is a maximum possible length of an identifier in python?
         
#    Ans) 79 characters.





#    Q13) What are the benefits of using python?
         
#    Ans)Python requires relatively fewer numbers of lines of code to perform the same operations and tasks done
#        in other programming languages with larger code blocks. it is also Easy to Read, Learn and Write
#        it  Improved Productivity, it is a Interpreted Language  it is also a Dynamically Typed programming language.
 


#    Q14) How is memory managed in python?
         
#    Ans) It involved the management of private heap.



#    Q15) How to isntall python in windows and set path variables?
#    Ans) Installation can be done through execution of software. In Variable name write path and in Variable value 
#          copy path up to C://Python(i.e., path where Python is installed). Click Ok ->Ok.


#    Q16) Is indentation required in python?
         
#    Ans) Yes proper indentation is required in python, improper indentation may give errors.
